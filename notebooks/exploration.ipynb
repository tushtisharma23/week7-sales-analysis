# %% [markdown]
# # Sales Data Exploration
#
# Week 7 - Sales Data Analysis Dashboard
#
# Author: Tushti Sharma
#
# This notebook performs basic exploration of the sales dataset.

# %%
import pandas as pd

df = pd.read_csv("../data/raw/sales_data.csv")

df.head()

# %%
df.info()

# %%
df.describe()

# %%
df.describe()
